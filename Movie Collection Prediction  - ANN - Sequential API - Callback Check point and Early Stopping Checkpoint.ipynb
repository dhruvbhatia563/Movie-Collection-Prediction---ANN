# %% [markdown]
# # Internshala Programming Practice Assignment
#
# ### Practice Assignment: Movie Collection Prediction
#
#  - This dataset contains data of movies, where our task is to predict the collection (revenue) the movie is going to make using variables such as expense, rating genre, etc. Please perform the following tasks
#
#  -  Import ‘Movie_collection’ csv files in data_x and data_y variables.
#  -  Look at the shape and first five rows of both dataframes to understand the data
#  -  Split the data into test, train, and validation
#  -  Take a look at the shape of the test, train, and validation set
#  -  Standardize the data
#  -  Create an ANN model with 2 dense layers of 30 neurons each
#  -  Compile the model with loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-2) and metrics=['mae'])
#  -  Train the model for 100 epochs
#  -  Evaluate the model performance on the test set
#  -  Predict the values of the first 5 test records

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Objective :  To predict the revenue of the movie

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_x = pd.read_csv('Movie_collection_Independent.csv')

# %%
data_y = pd.read_csv("Movie_collection_Target.csv")

# %%
data_x.head()
# Out:
#    Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0           20.1264               59.62               0.462  36524.125
# 1           20.5462               69.14               0.531  35668.655
# 2           20.5458               69.14               0.531  39912.675
# 3           20.6474               59.36               0.542  38873.890
# 4           21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# 0            7.995           7.94         527367      109.60          223.840
# 1            7.470           7.44         494055      146.64          243.456
# 2            7.515           7.44         547051      147.88         2022.400
# 3            7.020           8.26         516279      185.36          225.344
# 4            7.070           8.26         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  3D_available  Genre_Thriller  Genre_Drama  \
# 0              23            494             1               1            0
# 1              42            462             0               0            1
# 2              38            458             0               0            0
# 3              45            472             1               0            1
# 4              55            395             0               0            1
#
#    Genre_Comedy
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0

# %%
data_y.head()
# Out:
#    Collection
# 0    2.266667
# 1    2.106667
# 2    2.980000
# 3    2.893333
# 4    3.080000

# %%
data_x.shape
# Out:
# (506, 19)

# %%
data_y.shape
# Out:
# (506, 1)

# %%
data_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketin_expense     506 non-null    float64
#  1   Production_expense   506 non-null    float64
#  2   Multiplex_coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  Time_taken           506 non-null    float64
#  12  Twitter_hastags      506 non-null    float64
#  13  Avg_age_actors       506 non-null    int64
#  14  Num_multiplex        506 non-null    int64
#  15  3D_available         506 non-null    int64
#  16  Genre_Thriller       506 non-null    int64
#  17  Genre_Drama          506 non-null    int64
#  18  Genre_Comedy         506 non-null    int64
# dtypes: float64(12), int64(7)
# memory usage: 75.2 KB

# %% [markdown]
# ### Spliting the dataset into Train-Test and Validation set

# %%
from sklearn.model_selection import train_test_split
X_train_full, X_test, y_train_full, y_test = train_test_split(data_x, data_y, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((284, 19), (95, 19), (127, 19))

# %%
y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((284, 1), (95, 1), (127, 1))

# %% [markdown]
# ### Standardize the Data

# %%
# Standardizing
# a process in which --> we subtract the mean of each varriable from there individual values and then
# also divided by the varriance --> becuase at the end we want all the varriables with mean as '0' and varriance as '1'

# standard procedure to create any ML Model

# scaler is trained on training dataset only becuase we do ot want information from test/valid set to influence model training

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
# fitting the scaler object on trainign data
X_train = scaler.fit_transform(X_train) # scaler will find values to subtract as a mean and to divide as a varriance
X_valid = scaler.transform(X_valid) # transforming validation set using the sclaer object fitted on X_train
X_test = scaler.transform(X_test) # transforming test set using the sclaer object fitted on X_train

# %%
# to generate the same result everytime the code is being runned
np.random.seed(42)
tf.random.set_seed(42)

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((284, 19), (95, 19), (127, 19))

# %% [markdown]
# ### ANN model with 2 dense layers of 30 neurons each

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# input layer
# first dense layer with 30 neurons
# second dense layer with another 30 neurons
# as this is a regression pblm --> single output neuron without any activation function --> single neuron as want
# continuous value as output

# %%
# Sequential API

model = keras.models.Sequential([
    keras.layers.Dense(30,activation="relu",input_shape=[19]), #first_layer
    keras.layers.Dense(30,activation="relu"), # second_layer
    keras.layers.Dense(1)]) #output_layer

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                600
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 1,561
# Trainable params: 1,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model with :
#  - loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-2) and metrics=['mae'])

# %%
# Compiling the model

model.compile(loss="mean_squared_error", # square of the difference of predicted value & actual value
              optimizer=keras.optimizers.SGD(learning_rate=1e-3), # learnign rate --> lr - default value=0.01
              metrics=["mae"]) # mean_absolute_error = difference between the predicted value and actual value

# %% [markdown]
# ### Train the model for 100 epochs

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("movie_revenue_pridction_model.h5", save_best_only=True)

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)

# %%
history = model.fit(X_train,y_train,epochs=100, validation_data=(X_valid,y_valid), 
                    callbacks=[checkpoint_cb,early_stopping_cb])
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 20ms/step - loss: 7.6430 - mae: 2.6619 - val_loss: 7.4087 - val_mae: 2.6199
# Epoch 2/100
# 9/9 [==============================] - 0s 3ms/step - loss: 5.8750 - mae: 2.3122 - val_loss: 5.9614 - val_mae: 2.3288
# Epoch 3/100
# 9/9 [==============================] - 0s 3ms/step - loss: 4.6160 - mae: 2.0258 - val_loss: 4.8729 - val_mae: 2.0806
# Epoch 4/100
# 9/9 [==============================] - 0s 3ms/step - loss: 3.6731 - mae: 1.7794 - val_loss: 4.0252 - val_mae: 1.8648
# Epoch 5/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.9491 - mae: 1.5607 - val_loss: 3.3547 - val_mae: 1.6778
# Epoch 6/100
# 9/9 [==============================] - 0s 3ms/step - loss: 2.3923 - mae: 1.3747 - val_loss: 2.8238 - val_mae: 1.5114
# Epoch 7/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.9661 - mae: 1.2156 - val_loss: 2.4016 - val_mae: 1.3662
# Epoch 8/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.6400 - mae: 1.0785 - val_loss: 2.0719 - val_mae: 1.2436
# Epoch 9/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.3952 - mae: 0.9743 - val_loss: 1.8075 - val_mae: 1.1413
# Epoch 10/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.2086 - mae: 0.8917 - val_loss: 1.5983 - val_mae: 1.0606
# Epoch 11/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0697 - mae: 0.8300 - val_loss: 1.4333 - val_mae: 0.9933
# Epoch 12/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9661 - mae: 0.7838 - val_loss: 1.3026 - val_mae: 0.9405
# Epoch 13/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8869 - mae: 0.7497 - val_loss: 1.1951 - val_mae: 0.8962
# Epoch 14/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8245 - mae: 0.7182 - val_loss: 1.1079 - val_mae: 0.8587
# Epoch 15/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.
100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1787 - mae: 0.3181 - val_loss: 0.2246 - val_mae: 0.3749
# Epoch 89/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1770 - mae: 0.3164 - val_loss: 0.2226 - val_mae: 0.3732
# Epoch 90/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1755 - mae: 0.3151 - val_loss: 0.2208 - val_mae: 0.3717
# Epoch 91/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1741 - mae: 0.3137 - val_loss: 0.2188 - val_mae: 0.3698
# Epoch 92/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1728 - mae: 0.3125 - val_loss: 0.2168 - val_mae: 0.3680
# Epoch 93/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1714 - mae: 0.3111 - val_loss: 0.2151 - val_mae: 0.3664
# Epoch 94/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1702 - mae: 0.3098 - val_loss: 0.2138 - val_mae: 0.3654
# Epoch 95/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1688 - mae: 0.3086 - val_loss: 0.2122 - val_mae: 0.3641
# Epoch 96/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1675 - mae: 0.3072 - val_loss: 0.2106 - val_mae: 0.3625
# Epoch 97/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1662 - mae: 0.3059 - val_loss: 0.2087 - val_mae: 0.3607
# Epoch 98/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1652 - mae: 0.3051 - val_loss: 0.2072 - val_mae: 0.3593
# Epoch 99/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1639 - mae: 0.3038 - val_loss: 0.2057 - val_mae: 0.3578
# Epoch 100/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1627 - mae: 0.3025 - val_loss: 0.2042 - val_mae: 0.3564

# %%
# plotting the model history

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
del model

# %%
keras.backend.clear_session()

# %%
model = keras.models.load_model("movie_revenue_pridction_model.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                600
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 1,561
# Trainable params: 1,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 0s 998us/step - loss: 0.2473 - mae: 0.3684
# [0.2472868710756302, 0.3683830499649048]

# %%
X_new = X_test[:5]
X_new
# Out:
# array([[-0.44266208, -1.02614886,  0.38963381,  0.17868888,  0.53249944,
#          0.51973978,  0.49371081,  0.54760731,  0.56866681, -0.29573723,
#          0.24587303,  1.2119233 , -1.47737723,  1.65755423, -0.06831227,
#          0.83094897, -0.72586619, -0.50659369,  1.48020648],
#        [-0.4472429 , -0.69071378,  0.92307081,  0.66563386, -1.30219665,
#         -0.07919485, -0.13613263, -0.16729666, -0.04627728,  0.8956014 ,
#          0.86778136,  1.68205187, -0.21397019, -0.67366446, -1.12199413,
#         -1.20344334,  1.37766439, -0.50659369, -0.67558142],
#        [-0.44085257,  2.34099388, -0.44862433, -0.43782334,  1.05925789,
#          0.92200931,  0.88680459,  0.86287552,  0.85145132, -1.33815853,
#         -0.98658199, -0.48441691,  0.91469946,  0.69291202,  0.14427266,
#         -1.20344334, -0.72586619, -0.50659369,  1.48020648],
#        [-0.44268023, -0.06532636,  1.21095744, -0.32107045, -2.20162774,
#         -0.64237218, -0.57389615, -0.71346553, -0.65673272, -1.07010734,
#          0.72351318, -1.22111323, -1.48128267, -1.47753297, -1.72277764,
#         -1.20344334,  1.37766439, -0.50659369, -0.67558142],
#        [ 0.20523665,  0.97082689, -1.32921874,  0.0092548 ,  0.80842054,
#          0.68958692,  0.63218703,  0.7252232 ,  0.58213274,  0.12123129,
#         -0.56643381, -0.69645944,  1.53712758, -1.39714612,  0.91142699,
#         -1.20344334, -0.72586619, -0.50659369,  1.48020648]])

# %%
y_pred = model.predict(X_new)

# %%
print(y_pred) # predicted_y
# Out:
# [[2.4928281]
#  [2.4419906]
#  [1.7999651]
#  [2.3888502]
#  [1.5561042]]

# %%
print(y_test[:5]) # actual_y
# Out:
#      Collection
# 173    2.240000
# 274    2.826667
# 491    1.573333
# 72     2.186667
# 452    1.740000
